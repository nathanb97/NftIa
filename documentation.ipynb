# %%
1 ere solution prendre plein de NFT, faire tourner le Qgan dessus
2 eme solution prendre des NFT les passer en 3D
3 eme solution faire des NFT algorithmiquement

Solution en recherche :
    - Donner un physique de base
    - Et demander au Gan de creer des variantes
# Out:
#   Input In [1]
#     1 ere solution prendre plein de NFT, faire tourner le Qgan dessus
#       ^
# SyntaxError: invalid syntax

# %% [raw]
# https://www.youtube.com/watch?v=4QC_Pp04vP4
# Dans cette vidéo interessant car il explique comment declarer un Nft
# Il utilise une IA qui fait de l'art à partir d'un texte
# Ce genre de modèles s'appellent des GAN : generative adversarial network

# %% [markdown]
# # Théorie des Gans Science for all

# %% [raw]
# https://www.youtube.com/watch?v=JikwRMXJzk0
# Science for all a fait une vidéo dessus
# Il y a un reseau de neurone générateur chargé de crée des Fake, et un adversarial qui à le role de dire ce qui est bien ou mal

# %%
from IPython import display
display.Image("architecture_gan.png")

# %% [raw]
# L'apprentissage se fait en 2 étapes
#
# Example de réseaux.
# https://arxiv.org/abs/1609.04802 permet d'augmenter la résolution.
# ai reconstructs photos with realistic results online permet de reconstruire image.
# Ils marchent avec une loss bayesiennes.

# %% [markdown]
# # Fin de la théorie

# %% [raw]
# Il à éssayer https://deepai.org/
# Ensuite il à VQGan & clip :
# https://www.youtube.com/watch?v=2hgfbf5OOoI
# sport racer48s pritty

# %% [raw]
# https://www.youtube.com/watch?v=BMq2Jrvp9AA nulle
# https://www.youtube.com/watch?v=jZfV9Aabek4 celui la à l'air pas mal

# %% [markdown]
# # Article faire des NFT VQGan & clip

# %% [raw]
# https://betterprogramming.pub/create-nft-art-with-artificial-intelligence-using-python-6e181e930f95
# Il utilise Pixray qui utilise VQGan & clip

# %% [markdown]
# # Autres Gans

# %%
https://neptune.ai/blog/6-gan-architectures

# %% [raw]
# Vanilla gan pour generer ecriture je crois
# CycleGAN pour une transformation entre des images de cheval et de zèbre,
#     https://www.youtube.com/watch?v=4LktBHGCNfw
# StyleGAN : c'est celui de qui nous interesse :  https://github.com/NVlabs/stylegan
# lsGAN est pas mal : https://github.com/xudonmao/LSGAN

# %% [markdown]
# # Algorithmiquement

# %% [raw]
# https://www.youtube.com/watch?v=3WBjT1B65AM
# Dans cette vidéo il utilise ça :
#
# https://github.com/Solseum/solseum-nft-generator

# %%
Un bon c'est 
https://github.com/HashLips
https://github.com/HashLips/generative-art-node
https://www.youtube.com/channel/UC1LV4_VQGBJHTJjEWUmy8nA
    
https://nft-inator.com/
    
https://tokenizedhq.com/nft-generator/

# %% [markdown]
# # Acheter un NFT de gorille

# %% [raw]
# https://www.quora.com/How-do-I-buy-an-NFT-monkey
# Ils disent qu'on peut acheter sur :
# https://www.rarepuppy.com/ mais ça marche pas

# %%
Moi j'ai trouvé : 
https://www.binance.com/en/nft/search-result?ref=HDYAHEES&tab=nft&keyword=monkey&order=set_end_time%401
    
https://www.binance.com/en/nft/home?ads=true&utm_source=googleadwords_int&utm_medium=cpc&utm_campaign=paid_NFT&ref=HDYAHEES&gclid=Cj0KCQjwhqaVBhCxARIsAHK1tiNQ6aIe7sPHaMdbuxwxQ-NOFQKkRYrZboGozi40RzMbZYsN2--r06kaAumcEALw_wcB

# %%
#
